# %%
def mymethod():e
    print("aa")
    
mymethod()
# Out:
# aa

# %%
def m2 (i):
    if i==2:
        print ("Oye bae")
    else:
        print ("elsaa")
        
m2(3)
# Out:
# elsaa

# %%
def myv(ww):
    return ww+2
v2 = myv
output = v2(5) 
print (output)
# Out:
# 7

# %%
def add(x,y):
    return x+y

def do_tw(func, x,y):
    return func(7,7)

a =5
b = 10
print (do_tw(add, a, b))
# Out:
# 14

# %%
import random

for i in range(500):
    value = random.randint(1,500)
    print (value)
# Out:
# 395
# 100
# 300
# 329
# 274
# 461
# 253
# 221
# 71
# 500
# 490
# 256
# 264
# 362
# 357
# 295
# 441
# 439
# 442
# 38
# 401
# 378
# 358
# 300
# 188
# 278
# 227
# 363
# 57
# 212
# 482
# 439
# 303
# 166
# 24
# 156
# 162
# 353
# 13
# 352
# 65
# 207
# 340
# 440
# 397
# 284
# 431
# 72
# 228
# 462
# 277
# 332
# 247
# 73
# 217
# 346
# 375
# 63
# 262
# 244
# 181
# 178
# 42
# 329
# 246
# 128
# 305
# 490
# 414
# 338
# 198
# 152
# 11
# 264
# 216
# 250
# 20
# 41
# 312
# 168
# 77
# 1
# 433
# 205
# 443
# 276
# 147
# 470
# 7
# 92
# 277
# 315
# 475
# 128
# 294
# 437
# 12
# 327
# 115
# 57
# 320
# 121
# 178
# 1
# 248
# 50
# 206
# 30
# 241
# 470
# 195
# 126
# 284
# 93
# 80
# 338
# 460
# 122
# 462
# 60
# 283
# 369
# 298
# 496
# 79
# 305
# 311
# 242
# 104
# 190
# 157
# 491
# 293
# 428
# 481
# 92
# 425
# 329
# 100
# 467
# 398
# 192
# 470
# 424
# 77
# 328
# 15
# 210
# 382
# 44
# 366
# 367
# 66
# 151
# 475
# 210
# 271
# 100
# 72
# 330
# 118
# 374
# 242
# 327
# 224
# 385
# 26
# 127
# 104
# 396
# 37
# 30
# 322
# ...

# %%
from math import pi as vai
print (vai)
# Out:
# 3.141592653589793

# %%
def pn(x):
    for i in range(x):
        print (i)
        return
pn(10)
# Out:
# 0

# %%
def func():
    res =0
    for i in range(4):
        res +=i
    return res

func()
# Out:
# 6

# %%
print (0)
assert "h" != "w"
print (1)
assert True
print (2)
assert True
print (3)
# Out:
# 0
# 1
# 2
# 3

# %%
file = open("mf.txt", "r")
cont = file.readlines()
print(cont)

with open ("mf.txt") as f:
    print (f.read())

file.close()
# Out:
# ['shoib islam']
# shoib islam
